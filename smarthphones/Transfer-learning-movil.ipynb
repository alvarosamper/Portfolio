# %%
import cv2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Instalación del darknet

# %%
# !git clone https://github.com/AlexeyAB/darknet.git
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 15502, done.
# remote: Total 15502 (delta 0), reused 0 (delta 0), pack-reused 15502
# Receiving objects: 100% (15502/15502), 14.16 MiB | 23.13 MiB/s, done.
# Resolving deltas: 100% (10405/10405), done.

# %%
# %cd darknet
# Out:
# /content/darknet

# %% [markdown]
# ## Construcción del darkent con OpenCV, CUDA y cuDNN

# %%
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile

print("Building. . . It might take 2-3 minutes")

# !make &> build_log.txt
# Out:
# Building. . . It might take 2-3 minutes

# %% [markdown]
# Entrenamiento

# %%
# !./darknet detector train /content/drive/MyDrive/movil-final/imagenes/cell-phone.data /content/drive/MyDrive/movil-final/cell-yolov3.cfg /content/drive/MyDrive/movil-final/backup/yolov3.weights -dont_show -i 0 -map -clear
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
#  total_bbox = 118470, rewritten_bbox = 0.001688 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 1, class_loss = 0.004359, iou_loss = 0.000000, total_loss = 0.004359
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.731201), count: 3, class_loss = 0.354566, iou_loss = 0.191344, total_loss = 0.545909
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.005630, iou_loss = 0.000000, total_loss = 0.005630
#  total_bbox = 118473, rewritten_bbox = 0.001688 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.755086), count: 2, class_loss = 0.464097, iou_loss = 0.120118, total_loss = 0.584215
# ...
